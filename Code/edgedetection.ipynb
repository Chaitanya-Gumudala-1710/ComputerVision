# %% [markdown]
# ### Loading the required Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/home/chaitanya/computer_vision/images/"

# %% [markdown]
# ##### Loading the building image

# %%
building_image_path = path + "building.jpeg"
building_image = cv2.imread(building_image_path, cv2.IMREAD_GRAYSCALE)
# Printing the size of the color image
print('Size of the image is :', building_image.shape)
plt.figure(figsize=(6, 6))
plt.imshow(building_image, cmap="gray")
plt.title("Building Image")
plt.show()
# Out:
# Size of the image is : (710, 1260)

# %% [markdown]
# ##### Applying sobel kernel for edge detection

# %%
sobel_kernel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
sobel_kernel_y = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])

# %%
sobel_gradient_x = cv2.filter2D(building_image, -1, sobel_kernel_x)
sobel_gradient_y = cv2.filter2D(building_image, -1, sobel_kernel_y)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(sobel_gradient_x, cmap="gray")
plt.title("Sobel kernel in x-direction")
plt.subplot(1, 2, 2)
plt.imshow(sobel_gradient_y, cmap="gray")
plt.title("Sobel kernel in y-direction")
plt.show()

# %%
sobel_magnitude = np.sqrt(sobel_gradient_x ** 2 + sobel_gradient_y ** 2)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(building_image, cmap="gray")
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(sobel_magnitude, cmap="gray")
plt.title("Image after applying sobel kernel(magnitude)")
plt.show()

# %%
sobel_direction = np.arctan2(sobel_gradient_x, sobel_gradient_y)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(building_image, cmap="gray")
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(sobel_direction, cmap="gray")
plt.title("Image after applying sobel kernel(direction)")
plt.show()

# %% [markdown]
# ##### Applying prewitt kernel for edge detection

# %%
prewitt_x = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]])
prewitt_y = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])

# %%
prewitt_gradient_x = cv2.filter2D(building_image, -1, prewitt_x)
prewitt_gradient_y = cv2.filter2D(building_image, -1, prewitt_y)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(prewitt_gradient_x, cmap="gray")
plt.title("Prewitt kernel in x-direction")
plt.subplot(1, 2, 2)
plt.imshow(prewitt_gradient_y, cmap="gray")
plt.title("Prewitt kernel in y-direction")
plt.show()

# %%
prewitt_magnitude = np.sqrt(prewitt_gradient_x ** 2 + prewitt_gradient_y ** 2)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(building_image, cmap="gray")
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(prewitt_magnitude, cmap="gray")
plt.title("Image after applying prewitt kernel(magnitude)")
plt.show()

# %%
prewitt_direction = np.arctan2(prewitt_gradient_x, prewitt_gradient_y)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(building_image, cmap="gray")
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(prewitt_direction, cmap="gray")
plt.title("Image after applying prewitt kernel(direction)")
plt.show()

# %% [markdown]
# ##### Applying Roberts kernel for edge detection

# %%
roberts_x = np.array([[0, 1], [-1, 0]])
roberts_y = np.array([[1, 0], [0, -1]])

# %%
roberts_gradient_x = cv2.filter2D(building_image, -1, roberts_x)
roberts_gradient_y = cv2.filter2D(building_image, -1, roberts_y)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(roberts_gradient_x, cmap="gray")
plt.title("Roberts kernel in x-direction")
plt.subplot(1, 2, 2)
plt.imshow(roberts_gradient_y, cmap="gray")
plt.title("Roberts kernel in y-direction")
plt.show()

# %%
roberts_magnitude = np.sqrt(roberts_gradient_x ** 2 + roberts_gradient_y ** 2)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(building_image, cmap="gray")
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(roberts_magnitude, cmap="gray")
plt.title("Image after applying roberts kernel(magnitude)")
plt.show()

# %%
roberts_direction = np.arctan2(roberts_gradient_x, roberts_gradient_y)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(building_image, cmap="gray")
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(roberts_direction, cmap="gray")
plt.title("Image after applying robert kernel(direction)")
plt.show()

# %% [markdown]
# ##### Comparing all three kernels for edge detection

# %%
plt.figure(figsize=(24, 6))
plt.subplot(1, 4, 1)
plt.imshow(building_image, cmap="gray")
plt.title("Original image")
plt.subplot(1, 4, 2)
plt.imshow(sobel_magnitude, cmap="gray")
plt.title("Sobel kernel(magnitude)")
plt.subplot(1, 4, 3)
plt.imshow(prewitt_magnitude, cmap="gray")
plt.title("Prewitt kernel(magnitude)")
plt.subplot(1, 4, 4)
plt.imshow(roberts_magnitude, cmap="gray")
plt.title("Roberts kernel(magnitude)")
plt.show()

# %%
plt.figure(figsize=(24, 6))
plt.subplot(1, 4, 1)
plt.imshow(building_image, cmap="gray")
plt.title("Original image")
plt.subplot(1, 4, 2)
plt.imshow(sobel_direction, cmap="gray")
plt.title("Sobel kernel(direction)")
plt.subplot(1, 4, 3)
plt.imshow(prewitt_direction, cmap="gray")
plt.title("Prewitt kernel(direction)")
plt.subplot(1, 4, 4)
plt.imshow(roberts_direction, cmap="gray")
plt.title("Roberts kernel(direction)")
plt.show()

# %% [markdown]
# ##### Applying Canny Edge Detector

# %%
blurred_building_image = cv2.GaussianBlur(building_image, (25, 25), 0)
canny_edge_detector = cv2.Canny(blurred_building_image, 5, 50)

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
plt.imshow(building_image, cmap="gray")
plt.title("Original Image")
plt.subplot(1, 3, 2)
plt.imshow(blurred_building_image, cmap="gray")
plt.title("Blurred Image")
plt.subplot(1, 3, 3)
plt.imshow(canny_edge_detector, cmap="gray")
plt.title("Canny edge detector")
plt.show()
